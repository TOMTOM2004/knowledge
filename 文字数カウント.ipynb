# %%
text = "私の強みは、表面的な数値の動きにとどまらず、その背後にある構造的な要因を捉える力です。複雑な現実を理解するには要素を分解し、仮説と検証を重ねることが必要だと考え、ゼミでは因果推論に注力してきました。卒業論文でも、今の日本における家計消費の実態をより現実に近い形で捉えることを目的に、足元の経済構造を分析し、公的統計に加えてオルタナティブデータも活用しながら、消費行動の変化を捉える設計に取り組んでいます。その際、地域差や消費行動の違いも踏まえながら分析することで、経済の動きをより立体的に把握しようとしています。さらに、長期インターンでもデータサイエンス業務を通じて、複雑な情報を整理し、分析結果を実務上の判断につなげる経験を重ねてきました。こうした姿勢を活かし、貴社でも業績や市場データの背後にある構造変化を整理し、投資判断の根拠を客観的かつ説得力を持って示せる人材を目指したいと考えています。"
print(len(text))
# Out:
# 398
